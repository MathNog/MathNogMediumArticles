# %%
import Pkg
Pkg.activate(".")
# Out:
#   Activating new project at `~/Documents/Medium/MathNogMediumArticles/TimeSeriesJulia/ScoreDrivenModels`

# %%
# Pkg.add("ScoreDrivenModels")
# Out:
#    Resolving package versions...
#     Updating `~/Documents/Medium/MathNogMediumArticles/TimeSeriesJulia/ScoreDrivenModels/Project.toml`
#   [4a87933e] + ScoreDrivenModels v0.2.1
#     Updating `~/Documents/Medium/MathNogMediumArticles/TimeSeriesJulia/ScoreDrivenModels/Manifest.toml`
#   [47edcb42] + ADTypes v1.14.0
#   [7d9f7c33] + Accessors v0.1.42
#   [79e6a3ab] + Adapt v4.3.0
#   [66dad0bd] + AliasTables v1.1.3
#   [4fba245c] + ArrayInterface v7.19.0
#   [861a8166] + Combinatorics v1.0.3
#   [38540f10] + CommonSolve v0.2.4
#   [bbf7d656] + CommonSubexpressions v0.3.1
#   [34da2185] + Compat v4.16.0
#   [a33af91c] + CompositionsBase v0.1.2
#   [187b0558] + ConstructionBase v1.5.8
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.18.22
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
# ⌅ [a0c0ee7d] + DifferentiationInterface v0.6.54
#   [31c24e10] + Distributions v0.25.120
#   [ffbed154] + DocStringExtensions v0.9.4
# ...

# %%
using ScoreDrivenModels
